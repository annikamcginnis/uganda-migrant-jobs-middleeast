# %%
import pandas as pd

# %%
pd.set_option('display.max_columns', None)

# %%
df_companies = pd.read_csv('companies.csv')

# %%
#df_companies.to_csv('companies_last.csv', index=False)

# %%
df_companies.head()
# Out:
#                                 company_name  \
# 0         RIGHTFORCE MANPOWER SERVICES L.L.C
# 1               FIXIT MANPOWER SUPPLY L.L.C.
# 2  B H R HUMAN RESOURCES CONSULTANCIES L.L.C
# 3              MEHAN HUMAN RESOURCES COMPANY
# 4                SHANKAR TRADING COMPANY LLC
#
#                                         company_link  \
# 0  https://eemis.mglsd.go.ug/companies/RIGHTFORCE...
# 1  https://eemis.mglsd.go.ug/companies/FixitManpo...
# 2  https://eemis.mglsd.go.ug/companies/BHRHUMANRE...
# 3  https://eemis.mglsd.go.ug/companies/MEHANHUMAN...
# 4  https://eemis.mglsd.go.ug/companies/SHANKARTRA...
#
#                company_location_companiespage    company_phone  \
# 0  As Sulimaniyah, Riyadh 12431, Saudi Arabia  +971-502-258556
# 1  As Sulimaniyah, Riyadh 12431, Saudi Arabia  +971-524-326554
# 2  As Sulimaniyah, Riyadh 12431, Saudi Arabia  +971-585-177862
# 3              Al khobar Dammam, Saudi Arabia  +996-539-115211
# ...

# %%
df_companies['company_name'] = df_companies['company_name'].str.upper()
#df_companies.head()

# %%
df_companies.shape
# Out:
# (495, 13)

# %%
df_companies['active_company'] = True
df_companies.head()
# Out:
#                                 company_name  \
# 0         RIGHTFORCE MANPOWER SERVICES L.L.C
# 1               FIXIT MANPOWER SUPPLY L.L.C.
# 2  B H R HUMAN RESOURCES CONSULTANCIES L.L.C
# 3              MEHAN HUMAN RESOURCES COMPANY
# 4                SHANKAR TRADING COMPANY LLC
#
#                                         company_link  \
# 0  https://eemis.mglsd.go.ug/companies/RIGHTFORCE...
# 1  https://eemis.mglsd.go.ug/companies/FixitManpo...
# 2  https://eemis.mglsd.go.ug/companies/BHRHUMANRE...
# 3  https://eemis.mglsd.go.ug/companies/MEHANHUMAN...
# 4  https://eemis.mglsd.go.ug/companies/SHANKARTRA...
#
#                company_location_companiespage    company_phone  \
# 0  As Sulimaniyah, Riyadh 12431, Saudi Arabia  +971-502-258556
# 1  As Sulimaniyah, Riyadh 12431, Saudi Arabia  +971-524-326554
# 2  As Sulimaniyah, Riyadh 12431, Saudi Arabia  +971-585-177862
# 3              Al khobar Dammam, Saudi Arabia  +996-539-115211
# ...

# %%
df_old_companies = pd.read_csv('companies_last.csv')
df_old_companies.head()
# Out:
#                                 company_name  \
# 0         RIGHTFORCE MANPOWER SERVICES L.L.C
# 1               FIXIT MANPOWER SUPPLY L.L.C.
# 2  B H R HUMAN RESOURCES CONSULTANCIES L.L.C
# 3              MEHAN HUMAN RESOURCES COMPANY
# 4                SHANKAR TRADING COMPANY LLC
#
#                                         company_link  \
# 0  https://eemis.mglsd.go.ug/companies/RIGHTFORCE...
# 1  https://eemis.mglsd.go.ug/companies/FixitManpo...
# 2  https://eemis.mglsd.go.ug/companies/BHRHUMANRE...
# 3  https://eemis.mglsd.go.ug/companies/MEHANHUMAN...
# 4  https://eemis.mglsd.go.ug/companies/SHANKARTRA...
#
#                company_location_companiespage    company_phone  \
# 0  As Sulimaniyah, Riyadh 12431, Saudi Arabia  +971-502-258556
# 1  As Sulimaniyah, Riyadh 12431, Saudi Arabia  +971-524-326554
# 2  As Sulimaniyah, Riyadh 12431, Saudi Arabia  +971-585-177862
# 3              Al khobar Dammam, Saudi Arabia  +996-539-115211
# ...

# %%
#df_old_companies = df_old_companies.drop(columns=['active_company'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[82], line 1
# ----> 1 df_old_companies = df_old_companies.drop(columns=['active_company'])
#
# File ~/.pyenv/versions/3.12.7/lib/python3.12/site-packages/pandas/core/frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
# ...

# %%
df_old_companies = df_old_companies.T.drop_duplicates().T

# %%
df_old_companies.shape
# Out:
# (495, 12)

# %%
#df_old_companies['company_name'] = df_old_companies['company_name'].str.upper()

# %%
common_columns = [col for col in df_old_companies.columns if col in df_companies.columns]
print("Common Columns:", common_columns)

# %%
df_merged_companies = pd.merge(df_old_companies, df_companies, on=['company_name', 'company_link', 'company_name_copg', 'company_location_companiespage', 'company_phone', 'company_calendar', 'logo_link', 'Licence No :', 'Start Date :', 'Expiry Date :', 'Address :', 'Phone :', 'Email :'], how='outer')

df_merged_companies = df_merged_companies.drop_duplicates()

df_merged_companies
# Out:
#                                      company_name  \
# 0                         5 KMG INTERNATIONAL LTD
# 1                   AALAM ALTASHIRAT  RECRUITMENT
# 2          ABBA PLACEMENTS RECRUITMENT AGENCY LTD
# 3    ABDULLAH YOUSAF ALMAZROUA RECRUITMENT OFFICE
# 4                    ABS CONSULTING GROUP LIMITED
# ..                                            ...
# 490                       YARA RECRUITMENT OFFICE
# 491             ZAHI ALLOWN PROJECT MANAGEMENT CO
# 492                 ZION WORLDWIDE PLACEMENTS LTD
# 493                   ZIRIKYASHI HOLDINGS (U) LTD
# 494                           ZONO AGENCY LIMITED
#
#                                           company_link  \
# 0    https://eemis.mglsd.go.ug/companies/5KMGINTERN...
# 1    https://eemis.mglsd.go.ug/companies/AALAMALTAS...
# 2    https://eemis.mglsd.go.ug/companies/ABBAPLACEM...
# 3    https://eemis.mglsd.go.ug/companies/AbdullahYo...
# 4    https://eemis.mglsd.go.ug/companies/ABSCONSULT...
# ...

# %%
df_merged_companies['active_company'].value_counts()
# Out:
# active_company
# True    495
# Name: count, dtype: int64

# %%
df_merged_companies['active_company'] = df_merged_companies['active_company'].fillna(False)

# %%
df_merged_companies['active_company'].value_counts()
# Out:
# active_company
# True    495
# Name: count, dtype: int64

# %%
df_merged_companies.head()
# Out:
#                                    company_name  \
# 0                       5 KMG INTERNATIONAL LTD
# 1                 AALAM ALTASHIRAT  RECRUITMENT
# 2        ABBA PLACEMENTS RECRUITMENT AGENCY LTD
# 3  ABDULLAH YOUSAF ALMAZROUA RECRUITMENT OFFICE
# 4                  ABS CONSULTING GROUP LIMITED
#
#                                         company_link  \
# 0  https://eemis.mglsd.go.ug/companies/5KMGINTERN...
# 1  https://eemis.mglsd.go.ug/companies/AALAMALTAS...
# 2  https://eemis.mglsd.go.ug/companies/ABBAPLACEM...
# 3  https://eemis.mglsd.go.ug/companies/AbdullahYo...
# 4  https://eemis.mglsd.go.ug/companies/ABSCONSULT...
#
#                       company_location_companiespage    company_phone  \
# 0                                        OLD KAMPALA  +256-709-696959
# 1  https://www.google.com/maps?sca_esv=567294360&...  +966-568-785468
# 2       NEXT TO UGANDA SWEATERS AFTER TOTAL KAMWOKYA  +256-760-863622
# ...

# %%
df_merged_companies.to_csv('companies_last.csv', index=False)

# %%
df_jobs = pd.read_csv('jobs.csv')

# %%
df_jobs.to_csv('jobs_last.csv', index=False)

# %%
df_jobs.head()
# Out:
#   job_name_jobs_list                      job_company_jobs_list  \
# 0         HOUSEMAIDS   HAM PROPERTY SERVICES AND MANAGEMENT LTD
# 1          housemaid  INTERNATIONAL EMPLOYMENT LINKAGES (U) LTD
# 2              Sales              MALISU APOLLO INVESTMENTS LTD
# 3         HOUSEMAIDS                 Peak Labour Giants Limited
# 4          HOUSEMAID                      DERM LOGISTICS UG LTD
#
#     job_page_link jobs_country_jobs_list            posted_date  \
# 0  ./jobs?id=6615                 Uganda  Posted : 02 Jan, 2025
# 1  ./jobs?id=6614                 Uganda  Posted : 02 Jan, 2025
# 2  ./jobs?id=6613                 Uganda  Posted : 03 Jan, 2025
# 3  ./jobs?id=6612                 Uganda  Posted : 02 Jan, 2025
# 4  ./jobs?id=6611                 Uganda  Posted : 02 Jan, 2025
#
#                   deadline job_salary_jobs_list  \
# 0  Deadline : 29 Jan, 2025              SAR 900
# 1  Deadline : 29 Jan, 2025              SAR 900
# ...

# %%
df_jobs = df_jobs.rename(columns={'job_company_jobs_list': 'company_name'})

# %%
df_jobs['company_name'] = df_jobs['company_name'].str.upper()
#df_jobs.head()

# %%
df_jobs['active_job'] = True

# %%
df_jobs.head()
# Out:
#   job_name_jobs_list                               company_name  \
# 0         HOUSEMAIDS   HAM PROPERTY SERVICES AND MANAGEMENT LTD
# 1          housemaid  INTERNATIONAL EMPLOYMENT LINKAGES (U) LTD
# 2              Sales              MALISU APOLLO INVESTMENTS LTD
# 3         HOUSEMAIDS                 PEAK LABOUR GIANTS LIMITED
# 4          HOUSEMAID                      DERM LOGISTICS UG LTD
#
#     job_page_link jobs_country_jobs_list            posted_date  \
# 0  ./jobs?id=6615                 Uganda  Posted : 02 Jan, 2025
# 1  ./jobs?id=6614                 Uganda  Posted : 02 Jan, 2025
# 2  ./jobs?id=6613                 Uganda  Posted : 03 Jan, 2025
# 3  ./jobs?id=6612                 Uganda  Posted : 02 Jan, 2025
# 4  ./jobs?id=6611                 Uganda  Posted : 02 Jan, 2025
#
#                   deadline job_salary_jobs_list  \
# 0  Deadline : 29 Jan, 2025              SAR 900
# 1  Deadline : 29 Jan, 2025              SAR 900
# ...

# %%
df_jobs.shape
# Out:
# (32, 19)

# %%
df_old_jobs = pd.read_csv('jobs_last.csv')
df_old_jobs.head()
# Out:
#   job_name_jobs_list                      job_company_jobs_list  \
# 0         HOUSEMAIDS   HAM PROPERTY SERVICES AND MANAGEMENT LTD
# 1          housemaid  INTERNATIONAL EMPLOYMENT LINKAGES (U) LTD
# 2              Sales              MALISU APOLLO INVESTMENTS LTD
# 3         HOUSEMAIDS                 Peak Labour Giants Limited
# 4          HOUSEMAID                      DERM LOGISTICS UG LTD
#
#     job_page_link jobs_country_jobs_list            posted_date  \
# 0  ./jobs?id=6615                 Uganda  Posted : 02 Jan, 2025
# 1  ./jobs?id=6614                 Uganda  Posted : 02 Jan, 2025
# 2  ./jobs?id=6613                 Uganda  Posted : 03 Jan, 2025
# 3  ./jobs?id=6612                 Uganda  Posted : 02 Jan, 2025
# 4  ./jobs?id=6611                 Uganda  Posted : 02 Jan, 2025
#
#                   deadline job_salary_jobs_list  \
# 0  Deadline : 29 Jan, 2025              SAR 900
# 1  Deadline : 29 Jan, 2025              SAR 900
# ...

# %%
df_old_jobs.shape
# Out:
# (32, 18)

# %%
df_old_jobs = df_old_jobs.rename(columns={'job_company_jobs_list': 'company_name'})

# %%
df_old_jobs['company_name'] = df_old_jobs['company_name'].str.upper()

# %%
#df_old_jobs = df_old_jobs.drop(columns=['active_job'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[141], line 1
# ----> 1 df_old_jobs = df_old_jobs.drop(columns=['active_job'])
#
# File ~/.pyenv/versions/3.12.7/lib/python3.12/site-packages/pandas/core/frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
# ...

# %%
df_old_jobs.shape
# Out:
# (32, 18)

# %%
common_columns = [col for col in df_old_jobs.columns if col in df_jobs.columns]
print("Common Columns:", common_columns)
# Out:
# Common Columns: ['job_name_jobs_list', 'company_name', 'job_page_link', 'jobs_country_jobs_list', 'posted_date', 'deadline', 'job_salary_jobs_list', 'job_page_full_url', 'job_name_job_page', 'company_name_job_page', 'job_country_job_page', 'job_time_job_page', 'job_salary_job_page', 'job_category', 'job_overview', 'job_description_details', 'company_reg_date', 'company_phone']

# %%
df_merged_jobs = pd.merge(df_old_jobs, df_jobs, on=['job_name_jobs_list', 'company_name', 'job_page_link', 'jobs_country_jobs_list', 'posted_date', 'deadline', 'job_salary_jobs_list', 'job_page_full_url', 'job_name_job_page', 'company_name_job_page', 'job_country_job_page', 'job_time_job_page', 'job_salary_job_page', 'job_category', 'job_overview', 'job_description_details', 'company_reg_date', 'company_phone'], how='outer')
df_merged_jobs = df_merged_jobs.drop_duplicates()
df_merged_jobs
# Out:
#         job_name_jobs_list                                    company_name  \
# 0   BIKE DELIVERY PERSONEL                    FRESH MIND INTERNATIONAL LTD
# 1          DOMESTIC WORKER           SAVIOURS INTERNATIONAL AGENCY LIMITED
# 2           FEMALE CLEANER                      VBC LABOUR EXPERTS LIMITED
# 3      Female House Driver                   ADVON SERVICES UGANDA LIMITED
# 4               HOUSE MAID                    ALKHAD IMPACT AGENCY LIMITED
# 5               HOUSE MAID         ALSALAM LOGISTICS & CONSULTANCY LIMITED
# 6               HOUSE MAID                          ELFIRSAN GROUP LIMITED
# 7               HOUSE MAID  FREE ZONE INTERNATIONAL RECRUITMENT AGENCY LTD
# 8               HOUSE MAID                           HIREON AGENCY LIMITED
# 9               HOUSE MAID                           HIREON AGENCY LIMITED
# 10              HOUSE MAID          SWIFT INTERNATIONAL RECRUITERS LIMITED
# ...

# %%
df_merged_jobs.shape
# Out:
# (32, 19)

# %%
#df_merged_jobs = df_merged_jobs.T.drop_duplicates().T

# %%
#df_merged_jobs.shape
# Out:
# (32, 19)

# %%
df_merged_jobs['active_job'] = df_merged_jobs['active_job'].fillna(False)

# %%
df_merged_jobs['active_job'].value_counts()
# Out:
# active_job
# True    32
# Name: count, dtype: int64

# %%
df_merged_jobs.head()
# Out:
#        job_name_jobs_list                           company_name  \
# 0  BIKE DELIVERY PERSONEL           FRESH MIND INTERNATIONAL LTD
# 1         DOMESTIC WORKER  SAVIOURS INTERNATIONAL AGENCY LIMITED
# 2          FEMALE CLEANER             VBC LABOUR EXPERTS LIMITED
# 3     Female House Driver          ADVON SERVICES UGANDA LIMITED
# 4              HOUSE MAID           ALKHAD IMPACT AGENCY LIMITED
#
#     job_page_link jobs_country_jobs_list                  posted_date  \
# 0  ./jobs?id=6589   United Arab Emirates  17 Dec, 2024 - 17 Dec, 2026
# 1  ./jobs?id=4101           Saudi Arabia  23 Aug, 2021 - 23 Aug, 2023
# 2  ./jobs?id=6601                 Uganda        Posted : 20 Dec, 2024
# 3  ./jobs?id=6588           Saudi Arabia  06 Jan, 2025 - 06 Jan, 2027
# 4  ./jobs?id=6592           Saudi Arabia  16 Dec, 2024 - 16 Dec, 2026
#
#                   deadline job_salary_jobs_list  \
# 0  Deadline : 09 Jan, 2025             AED 1850
# 1  Deadline : 12 Sep, 2027              SAR 900
# ...

# %%
df_merged_jobs = df_merged_jobs.drop_duplicates()

# %%
df_merged_jobs.to_csv('jobs_last.csv', index=False)

# %%
# common_columns = [col for col in df_merged_jobs.columns if col in df_merged_companies.columns]
# print("Common Columns:", common_columns)
# Out:
# Common Columns: ['company_name', 'company_phone']

# %%
merged_df = pd.merge(df_merged_companies, df_merged_jobs, on='company_name', how='left')
merged_df.head()
# Out:
#                                    company_name  \
# 0                       5 KMG INTERNATIONAL LTD
# 1                 AALAM ALTASHIRAT  RECRUITMENT
# 2        ABBA PLACEMENTS RECRUITMENT AGENCY LTD
# 3  ABDULLAH YOUSAF ALMAZROUA RECRUITMENT OFFICE
# 4                  ABS CONSULTING GROUP LIMITED
#
#                                         company_link  \
# 0  https://eemis.mglsd.go.ug/companies/5KMGINTERN...
# 1  https://eemis.mglsd.go.ug/companies/AALAMALTAS...
# 2  https://eemis.mglsd.go.ug/companies/ABBAPLACEM...
# 3  https://eemis.mglsd.go.ug/companies/AbdullahYo...
# 4  https://eemis.mglsd.go.ug/companies/ABSCONSULT...
#
#                       company_location_companiespage  company_phone_x  \
# 0                                        OLD KAMPALA  +256-709-696959
# 1  https://www.google.com/maps?sca_esv=567294360&...  +966-568-785468
# 2       NEXT TO UGANDA SWEATERS AFTER TOTAL KAMWOKYA  +256-760-863622
# ...

# %%
merged_df.shape
# Out:
# (500, 32)

# %%
merged_df['active_job'] = merged_df['active_job'].fillna(False)
# Out:
# /var/folders/mb/f5zh4qyd6sbf171lrlnmff040000gn/T/ipykernel_51390/3702450419.py:1: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   merged_df['active_job'] = merged_df['active_job'].fillna(False)

# %%
merged_df['active_company'] = merged_df['active_company'].fillna(False)

# %%
merged_df.head()
# Out:
#                                    company_name  \
# 0                       5 KMG INTERNATIONAL LTD
# 1                 AALAM ALTASHIRAT  RECRUITMENT
# 2        ABBA PLACEMENTS RECRUITMENT AGENCY LTD
# 3  ABDULLAH YOUSAF ALMAZROUA RECRUITMENT OFFICE
# 4                  ABS CONSULTING GROUP LIMITED
#
#                                         company_link  \
# 0  https://eemis.mglsd.go.ug/companies/5KMGINTERN...
# 1  https://eemis.mglsd.go.ug/companies/AALAMALTAS...
# 2  https://eemis.mglsd.go.ug/companies/ABBAPLACEM...
# 3  https://eemis.mglsd.go.ug/companies/AbdullahYo...
# 4  https://eemis.mglsd.go.ug/companies/ABSCONSULT...
#
#                       company_location_companiespage  company_phone_x  \
# 0                                        OLD KAMPALA  +256-709-696959
# 1  https://www.google.com/maps?sca_esv=567294360&...  +966-568-785468
# 2       NEXT TO UGANDA SWEATERS AFTER TOTAL KAMWOKYA  +256-760-863622
# ...

# %%
merged_df = merged_df.rename(columns= {'Licence No :': 'license_no'})

# %%
merged_df = merged_df.rename(columns= {'Start Date :': 'start_date'})

# %%
merged_df = merged_df.rename(columns= {'Expiry Date :': 'expiry_date'})

# %%
merged_df = merged_df.rename(columns= {'Address :': 'address'})

# %%
merged_df = merged_df.rename(columns= {'Phone :': 'phone_no'})

# %%
merged_df = merged_df.rename(columns= {'Email :': 'email'})
#merged_df.head()

# %%
merged_df.to_csv('companies_and_jobs.csv', index=False)
